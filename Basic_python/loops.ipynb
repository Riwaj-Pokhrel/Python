# %% [markdown]
# ### While Loop

# %%
count=5
while count>0:
    print(count)
    count-=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
count=0
while count<5:
    print(count)
    count=count+1
else:
    print('Count:',count)
# Out:
# 0
# 1
# 2
# 3
# 4
# Count: 5

# %% [markdown]
# ### Break and Continue

# %%
count = 0
while count < 5:
    print(count)
    count = count + 1
    if count == 3:
        break
# Out:
# 0
# 1
# 2

# %%
count=0
while count<5:
    if count==3:
        count=count+1
        continue
    print(count)
    count=count+1
# Out:
# 0
# 1
# 2
# 4

# %% [markdown]
# ### For Loop
# For loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).

# %%
numbers = [0, 1, 2, 3, 4, 5]
for number in numbers: # number is temporary name to refer to the list's items, valid only inside this loop
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
language = 'Python'
for letter in language:
    print(letter)


for i in range(0,5):
    print(language[i])
# Out:
# P
# y
# t
# h
# o
# n
# P
# y
# t
# h
# o

# %%
info={'first_name':'Riwaj','last_name':'Pokhrel','faculty':'BCT','skills':['html','css','js','python'],'age':20}
for i in info:
    print(i)

for key, values in info.items():
    print(key,values)
# Out:
# first_name
# last_name
# faculty
# skills
# age
# first_name Riwaj
# last_name Pokhrel
# faculty BCT
# skills ['html', 'css', 'js', 'python']
# age 20

# %%
numbers = (0,1,2,3,4,5)
for number in numbers:
    print(number)
    if number == 3:
        break
# Out:
# 0
# 1
# 2
# 3

# %%
numbers=[0,1,2,3,4,5]
for number in numbers:
    if number==3:
        continue
    print(number)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
numbers = (0,1,2,3,4,5)
for number in numbers:
    print(number)
    if number == 3:
        continue
    print('Next number should be ', number + 1) if number != 5 else print("loop's end") 
print('outside the loop')

#here  if the number equals 3, the step after the condition (but inside the loop) i.e print is skipped and the execution of the loop continues if there are any iterations left.
# Out:
# 0
# Next number should be  1
# 1
# Next number should be  2
# 2
# Next number should be  3
# 3
# 4
# Next number should be  5
# 5
# loop's end
# outside the loop
