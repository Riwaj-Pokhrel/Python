# %%
print(3+7)
print(3-7)
print(3*7)
print(7/3)
print(3/7)
print(3**2)
print(8%3)
print(7//3)
# Out:
# 10
# -4
# 21
# 2.3333333333333335
# 0.42857142857142855
# 9
# 2
# 2

# %%
print(type(4))
print(type(3.56))
print(type('Riwaj'))
print(type(5j))
print(type(4-6j))
print(type([1,2,'ram',1]))
print(type({'ram':5,6:7,8:'shyam'}))
print(type({1,1,3,4,False,True}))
print(type((1,1,'ram',True)))
print(type(True))
print(type(3==5))
print(type(zip([1,2],[3,4])))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'complex'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>
# <class 'tuple'>
# <class 'bool'>
# <class 'bool'>
# <class 'zip'>
